# %% [markdown]
# # project : data modelling with postgres

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ![2.png](attachment:2.png)
# ![3.png](attachment:3.png)

# %% [markdown]
# ![4.png](attachment:4.png)

# %% [markdown]
# ![5.png](attachment:5.png)

# %% [markdown]
# ![6.png](attachment:6.png)

# %% [markdown]
# # FOR SQL_QUERIES.PY

# %% [markdown]
# ## DROP TABLES WE USE
#  > songplay_table_drop = "DROP TABLE IF EXISTS songplays"
#  >
#  > user_table_drop = "DROP TABLE IF EXISTS users"
#  >
#  > song_table_drop = "DROP TABLE IF EXISTS songs"
#  >
#  > artist_table_drop = "DROP TABLE IF EXISTS artists"
#  >
#  > time_table_drop = "DROP TABLE IF EXISTS time"
#
# ## CREATE TABLES
#  WE USE
#   LIKE
#  > SONGPLAY_TABLE_CREATE = "CREATE TABLE IF NOT EXISTS SONGPLAYS(PARTS OF TABLE)"

# %% [markdown]
# ## FOR CREATE_TABLES.PY
#
#  > import psycopg2
#  >
#  > from sql_queries import create_table_queries, drop_table_queries

# %% [markdown]
# #### COMMAND USE FOR RUN CREATE_TABLES.PY
#
#  > %RUN FILE OR PYTHON FILE
#
#  > python create_tables.py in terminal

# %% [markdown]
# ## FOR ETL PROCESS
# IN ETL.IYPNB AND ETL.PY
# WE USING THIS COMMANDS
#  > import os
#  >
#  > import glob
#  >
#  > import psycopg2
#  >
#  > import pandas as pd
#  >
#  > from sql_queries import *
#  >
#  > import json

# %% [markdown]
# ## then test.ipynb for check all queries
# ## sample query
# ![Annotation%202020-05-18%20144242.png](attachment:Annotation%202020-05-18%20144242.png)
